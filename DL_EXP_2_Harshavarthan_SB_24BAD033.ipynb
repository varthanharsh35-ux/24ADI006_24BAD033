# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-10,10,200)

sigmoid=1/(1+np.exp(-x))
tanh=np.tanh(x)
relu=np.maximum(0,x)

plt.figure(figsize=(8,5))

plt.plot(x,sigmoid,label="Sigmoid")
plt.plot(x,tanh,label="Tanh")
plt.plot(x,relu,label="ReLU")

print("Harshavarthan SB 24BAD033")
plt.title("Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend()

plt.show()
# Out:
# Harshavarthan SB 24BAD033

# %%
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data=load_breast_cancer()

x=data.data
y=data.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

functions=["sigmoid","tanh","relu"]

for f in functions:

    print("\nActivation Function :",f)

    model=tf.keras.Sequential([
    tf.keras.layers.Dense(32,activation=f,input_shape=(30,)),
    tf.keras.layers.Dense(16,activation=f),
    tf.keras.layers.Dense(1,activation="sigmoid")
    ])

    model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

    history=model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=0
    )

    loss,acc=model.evaluate(x_test,y_test,verbose=0)
    print("Harshavarthan SB 24BAD033")
    print("Training Accuracy :",history.history["accuracy"][-1])
    print("Validation Accuracy :",history.history["val_accuracy"][-1])
    print("Training Loss :",history.history["loss"][-1])
    print("Validation Loss :",history.history["val_loss"][-1])
    print("Test Accuracy :",acc)
# Out:
# Activation Function : sigmoid
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9725274443626404
# Validation Accuracy : 0.9340659379959106
# Training Loss : 0.18671397864818573
# Validation Loss : 0.20689715445041656
# Test Accuracy : 0.9824561476707458
#
# Activation Function : tanh
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9862637519836426
# Validation Accuracy : 0.9670329689979553
# Training Loss : 0.05172580108046532
# Validation Loss : 0.09520971775054932
# Test Accuracy : 0.9824561476707458
#
# Activation Function : relu
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9917582273483276
# Validation Accuracy : 0.9560439586639404
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data=load_breast_cancer()

x=data.data
y=data.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

optimizers={
"SGD":tf.keras.optimizers.SGD(),
"Momentum":tf.keras.optimizers.SGD(momentum=0.9),
"RMSProp":tf.keras.optimizers.RMSprop(),
"Adam":tf.keras.optimizers.Adam()
}

for name,opt in optimizers.items():

    print("\nOptimizer :",name)

    model=tf.keras.Sequential([
    tf.keras.layers.Dense(32,activation="relu",input_shape=(30,)),
    tf.keras.layers.Dense(16,activation="relu"),
    tf.keras.layers.Dense(1,activation="sigmoid")
    ])

    model.compile(optimizer=opt,loss="binary_crossentropy",metrics=["accuracy"])

    history=model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=0
    )

    loss,acc=model.evaluate(x_test,y_test,verbose=0)
    print("Harshavarthan SB 24BAD033")
    print("Training Accuracy :",history.history["accuracy"][-1])
    print("Validation Accuracy :",history.history["val_accuracy"][-1])
    print("Training Loss :",history.history["loss"][-1])
    print("Validation Loss :",history.history["val_loss"][-1])
    print("Test Accuracy :",acc)

    plt.figure(figsize=(6,4))
    plt.plot(history.history["loss"],label="Training Loss")
    plt.plot(history.history["val_loss"],label="Validation Loss")
    plt.title(name+" Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    plt.figure(figsize=(6,4))
    plt.plot(history.history["accuracy"],label="Training Accuracy")
    plt.plot(history.history["val_accuracy"],label="Validation Accuracy")
    plt.title(name+" Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()
# Out:
# Optimizer : SGD
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9395604133605957
# Validation Accuracy : 0.9340659379959106
# Training Loss : 0.181752547621727
# Validation Loss : 0.17208239436149597
# Test Accuracy : 0.9473684430122375
# Optimizer : Momentum
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9945054650306702
# Validation Accuracy : 0.9780219793319702
# Training Loss : 0.03498486429452896
# Validation Loss : 0.07826228439807892
# Test Accuracy : 0.9824561476707458
# Optimizer : RMSProp
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9890109896659851
# Validation Accuracy : 0.9450549483299255
# ...

# %%
from google.colab import drive
import tensorflow as tf
import os

drive.mount('/content/drive')

model.save('/content/drive/MyDrive/ann_model.h5')

print("Model saved successfully!")

loaded_model=tf.keras.models.load_model('/content/drive/MyDrive/ann_model.h5')

print("Model loaded successfully!")

readme="""
# Deep Learning Lab - Experiment 2

## Comparative Study of Activation Functions and Optimization Algorithms

Tools Used:
- Python
- TensorFlow
- Google Colab
- GitHub

Activation Functions:
- Sigmoid
- Tanh
- ReLU

Optimizers:
- SGD
- Momentum
- RMSProp
- Adam
"""

with open("README.md","w") as f:
    f.write(readme)

print("README.md created successfully!")
print("Harshavarthan SB 24BAD033")
print("\nRun the following Git commands in a terminal after creating a GitHub repository:\n")

print("git init")
print("git add .")
print('git commit -m "Deep Learning Experiment 2"')
print("git branch -M main")
print("git remote add origin https://github.com/username/deep-learning-lab.git")
print("git push -u origin main")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved successfully!
# Model loaded successfully!
# README.md created successfully!
# Harshavarthan SB 24BAD033
#
# Run the following Git commands in a terminal after creating a GitHub repository:
#
# git init
# git add .
# git commit -m "Deep Learning Experiment 2"
# git branch -M main
# git remote add origin https://github.com/username/deep-learning-lab.git
# git push -u origin main
