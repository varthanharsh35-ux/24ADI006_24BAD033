# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-10,10,200)

sigmoid=1/(1+np.exp(-x))
tanh=np.tanh(x)
relu=np.maximum(0,x)

plt.figure(figsize=(8,5))

plt.plot(x,sigmoid,label="Sigmoid")
plt.plot(x,tanh,label="Tanh")
plt.plot(x,relu,label="ReLU")

print("Harshavarthan SB 24BAD033")
plt.title("Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend()

plt.show()
# Out:
# Harshavarthan SB 24BAD033

# %%
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data=load_breast_cancer()

x=data.data
y=data.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

functions=["sigmoid","tanh","relu"]

for f in functions:

    print("\nActivation Function :",f)

    model=tf.keras.Sequential([
    tf.keras.layers.Dense(32,activation=f,input_shape=(30,)),
    tf.keras.layers.Dense(16,activation=f),
    tf.keras.layers.Dense(1,activation="sigmoid")
    ])

    model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

    history=model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=0
    )

    loss,acc=model.evaluate(x_test,y_test,verbose=0)
    print("Harshavarthan SB 24BAD033")
    print("Training Accuracy :",history.history["accuracy"][-1])
    print("Validation Accuracy :",history.history["val_accuracy"][-1])
    print("Training Loss :",history.history["loss"][-1])
    print("Validation Loss :",history.history["val_loss"][-1])
    print("Test Accuracy :",acc)
# Out:
# Activation Function : sigmoid
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9670329689979553
# Validation Accuracy : 0.9450549483299255
# Training Loss : 0.17467337846755981
# Validation Loss : 0.18948565423488617
# Test Accuracy : 0.9912280440330505
#
# Activation Function : tanh
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9835164546966553
# Validation Accuracy : 0.9780219793319702
# Training Loss : 0.05454925447702408
# Validation Loss : 0.08995053172111511
# Test Accuracy : 0.9736841917037964
#
# Activation Function : relu
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9890109896659851
# Validation Accuracy : 0.9670329689979553
# Training Loss : 0.05494507774710655
# Validation Loss : 0.10175766795873642
# Test Accuracy : 0.9736841917037964

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data=load_breast_cancer()

x=data.data
y=data.target

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

optimizers={
"SGD":tf.keras.optimizers.SGD(),
"Momentum":tf.keras.optimizers.SGD(momentum=0.9),
"RMSProp":tf.keras.optimizers.RMSprop(),
"Adam":tf.keras.optimizers.Adam()
}

for name,opt in optimizers.items():

    print("\nOptimizer :",name)

    model=tf.keras.Sequential([
    tf.keras.layers.Dense(32,activation="relu",input_shape=(30,)),
    tf.keras.layers.Dense(16,activation="relu"),
    tf.keras.layers.Dense(1,activation="sigmoid")
    ])

    model.compile(optimizer=opt,loss="binary_crossentropy",metrics=["accuracy"])

    history=model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=0
    )

    loss,acc=model.evaluate(x_test,y_test,verbose=0)
    print("Harshavarthan SB 24BAD033")
    print("Training Accuracy :",history.history["accuracy"][-1])
    print("Validation Accuracy :",history.history["val_accuracy"][-1])
    print("Training Loss :",history.history["loss"][-1])
    print("Validation Loss :",history.history["val_loss"][-1])
    print("Test Accuracy :",acc)

    plt.figure(figsize=(6,4))
    plt.plot(history.history["loss"],label="Training Loss")
    plt.plot(history.history["val_loss"],label="Validation Loss")
    plt.title(name+" Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    plt.figure(figsize=(6,4))
    plt.plot(history.history["accuracy"],label="Training Accuracy")
    plt.plot(history.history["val_accuracy"],label="Validation Accuracy")
    plt.title(name+" Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()
# Out:
# Optimizer : SGD
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9532967209815979
# Validation Accuracy : 0.9560439586639404
# Training Loss : 0.18594838678836823
# Validation Loss : 0.20613166689872742
# Test Accuracy : 0.9649122953414917
# Optimizer : Momentum
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9890109896659851
# Validation Accuracy : 0.9670329689979553
# Training Loss : 0.043020106852054596
# Validation Loss : 0.10010530799627304
# Test Accuracy : 0.9649122953414917
# Optimizer : RMSProp
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9862637519836426
# Validation Accuracy : 0.9780219793319702
# Training Loss : 0.046387504786252975
# Validation Loss : 0.08648748695850372
# Test Accuracy : 0.9649122953414917
# Optimizer : Adam
# Harshavarthan SB 24BAD033
# Training Accuracy : 0.9835164546966553
# Validation Accuracy : 0.9670329689979553
# Training Loss : 0.046930015087127686
# Validation Loss : 0.09605461359024048
# Test Accuracy : 0.9736841917037964

# %%
import tensorflow as tf

model.save("ann_model.h5")

loaded_model=tf.keras.models.load_model("ann_model.h5")

print("Model saved successfully!")
print("Model loaded successfully!")

readme="""
# Deep Learning Lab

## Experiment 2

Comparative Study of Activation Functions and Optimization Algorithms

Tools Used
- Python
- TensorFlow
- Google Colab
- GitHub

Activation Functions
- Sigmoid
- Tanh
- ReLU

Optimizers
- SGD
- Momentum
- RMSProp
- Adam
"""

with open("README.md","w") as f:
    f.write(readme)

print("README.md created successfully!")

print("\nGitHub Commands\n")

print("git init")
print("git add .")
print('git commit -m "Deep Learning Experiment 2"')
print("git branch -M main")
print("git remote add origin https://github.com/varthanharsh35-ux/24ADI006_24BAD033.git")
print("git push -u origin main")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved successfully!
# Model loaded successfully!
# README.md created successfully!
#
# GitHub Commands
#
# git init
# git add .
# git commit -m "Deep Learning Experiment 2"
# git branch -M main
# git remote add origin https://github.com/varthanharsh35-ux/24ADI006_24BAD033.git
# git push -u origin main
